# %%
import pandas as pd
import matplotlib.pyplot as plt
import re

# %%
caminho = r"C:\Projetos\LearningDataAnalysis\dados\mediaEnemPorMunicipio.csv"

# %%
microdadosEnem = pd.read_csv(caminho, sep=",", encoding='ISO-8859-1')

# %%
microdadosEnem.columns.values
# Out:
# <StringArray>
# [      'Unnamed: 0', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
#         'SG_UF_ESC',        'CO_UF_ESC',       'NU_NOTA_MT',
#        'NU_NOTA_LC',       'NU_NOTA_CH',       'NU_NOTA_CN',
#   'NU_NOTA_REDACAO']
# Length: 10, dtype: str

# %%
mediaEnemPorMunicipio = (
    microdadosEnem
    .groupby(['CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC', 'SG_UF_ESC', 'CO_UF_ESC'], as_index=False)
    .mean(numeric_only=True)
    .sort_values(by='SG_UF_ESC')
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 3
#       1 mediaEnemPorMunicipio = (
#       2     microdadosEnem
# ----> 3     .groupby(['CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC', 'SG_UF_ESC', 'CO_UF_ESC'], as_index=False)
#       4     .mean(numeric_only=True)
#       5     .sort_values(by='SG_UF_ESC')
#       6 )
#
# File C:\Projetos\LearningDataAnalysis\analisedados\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File C:\Projetos\LearningDataAnalysis\analisedados\Lib\site-packages\pandas\core\frame.py:10817, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10814 if level is None and by is None:
#   10815     raise TypeError("You have to supply one of 'by' and 'level'")
# > 10817 return DataFrameGroupBy(
#   10818     obj=self,
#   10819     keys=by,
#   10820     level=level,
#   10821     as_index=as_index,
#   10822     sort=sort,
#   10823     group_keys=group_keys,
#   10824     observed=observed,
#   10825     dropna=dropna,
#   10826 )
#
# File C:\Projetos\LearningDataAnalysis\analisedados\Lib\site-packages\pandas\core\groupby\groupby.py:1095, in GroupBy.__init__(self, obj, keys, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1092 self.dropna = dropna
#    1094 if grouper is None:
# -> 1095     grouper, exclusions, obj = get_grouper(
#    1096         obj,
#    1097         keys,
#    1098         level=level,
#    1099         sort=sort,
#    1100         observed=observed,
#    1101         dropna=self.dropna,
#    1102     )
#    1104 self.observed = observed
#    1105 self.obj = obj
#
# File C:\Projetos\LearningDataAnalysis\analisedados\Lib\site-packages\pandas\core\groupby\grouper.py:901, in get_grouper(obj, key, level, sort, observed, validate, dropna)
#     899         in_axis, level, gpr = False, gpr, None
#     900     else:
# --> 901         raise KeyError(gpr)
#     902 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     903     # Add key to exclusions
#     904     exclusions.add(gpr.key)
#
# KeyError: 'CO_MUNICIPIO_ESC'

# %%
mediaEnemPorMunicipio
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 mediaEnemPorMunicipio
#
# NameError: name 'mediaEnemPorMunicipio' is not defined

# %%
mediaEnemPorMunicipio.to_csv("mediaEnemPorMunicipio.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 mediaEnemPorMunicipio.to_csv("mediaEnemPorMunicipio.csv", index=False)
#
# NameError: name 'mediaEnemPorMunicipio' is not defined
