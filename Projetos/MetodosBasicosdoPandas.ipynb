# %%
import matplotlib as plt

# %%
import pandas as pd

# %%
caminho = r"C:\Projetos\LearningDataAnalysis\dados\microdados_enem_2018\DADOS\MICRODADOS_ENEM_2018.csv"

# %%
microdadosEnem = pd.read_csv(caminho, sep=";", encoding='ISO-8859-1', nrows=2000000)

# %%
colunasSelecionadas = ['TP_SEXO', 'NU_NOTA_REDACAO']

# %%
microdadosEnemSexoRedacao = microdadosEnem.filter(items=colunasSelecionadas)

# %%
microdadosEnemSexoRedacao.dropna()
# Out:
#         TP_SEXO  NU_NOTA_REDACAO
# 0             F            360.0
# 1             F            420.0
# 2             M            600.0
# 3             F            800.0
# 4             F            500.0
# ...         ...              ...
# 1999994       F            680.0
# 1999996       F            640.0
# 1999997       M            620.0
# 1999998       F            580.0
# 1999999       M            580.0
#
# [1576585 rows x 2 columns]

# %%
microdadosEnemSexoRedacao.head()
# Out:
#   TP_SEXO  NU_NOTA_REDACAO
# 0       F            360.0
# 1       F            420.0
# 2       M            600.0
# 3       F            800.0
# 4       F            500.0

# %%
microdadosEnemSexoRedacao.groupby('TP_SEXO').count()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                 995857
# M                 580728

# %%
microdadosEnemSexoRedacao.groupby('TP_SEXO').max()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                 1000.0
# M                 1000.0

# %%
microdadosEnemSexoRedacao[microdadosEnemSexoRedacao.NU_NOTA_REDACAO > 0].groupby('TP_SEXO').min()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                   40.0
# M                   40.0

# %%
microdadosEnemSexoRedacao.groupby('TP_SEXO').mean()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F             523.909557
# M             514.300120

# %%
microdadosEnemSexoRedacao.groupby('TP_SEXO').median()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                  520.0
# M                  520.0

# %%
microdadosEnemSexoRedacao.groupby('TP_SEXO').hist()
# Out:
# TP_SEXO
# F    [[Axes(0.125,0.11;0.775x0.77)]]
# M    [[Axes(0.125,0.11;0.775x0.77)]]
# dtype: object

# %%
microdadosEnemSexoRedacao.groupby('TP_SEXO').describe()
# Out:
#         NU_NOTA_REDACAO                                                    \
#                   count        mean         std  min    25%    50%    75%
# TP_SEXO
# F              995857.0  523.909557  189.460209  0.0  360.0  520.0  640.0
# M              580728.0  514.300120  191.926569  0.0  360.0  520.0  640.0
#
#
#             max
# TP_SEXO
# F        1000.0
# M        1000.0
